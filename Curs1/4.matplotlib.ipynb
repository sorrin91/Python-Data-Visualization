# %%
import matplotlib.pyplot as plt

# %%
plt.pie([1, 2, 1, 1])
# Out:
# ([<matplotlib.patches.Wedge at 0x1b55b960ec0>,
# ...
#  [Text(0.8899186825075615, 0.6465637930815537, ''),
#   Text(-0.8899187390319623, 0.6465637152823859, ''),
#   Text(-0.33991831634615544, -1.046162290570825, ''),
#   Text(0.8899186414035474, -0.6465638496563697, '')])

# %%
plt.bar([10, 12], [5, 7]);
